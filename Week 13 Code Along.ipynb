# %% [markdown]
# # Code Along

# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

## Change username and password to match your personal MySQL Server settings
username = 'root' # default username for MySQL db is root
password = 'root' # whatever password you chose during MySQL installation.

connection = f'mysql+pymysql://root:root@localhost/Chinook'
engine = create_engine(connection)

# %% [markdown]
# ![ERD.png](attachment:ERD.png))

# %% [markdown]
# What is the most a customer has spent on a single purchase and what is their customerId?

# %%
q = '''SELECT 
    customerid, Total
FROM
    Invoice
ORDER BY Total DESC
LIMIT 1'''
pd.read_sql(q,engine)
# Out:
#    customerid  Total
# 0           6  25.86

# %%
q = """SHOW TABLES"""
pd.read_sql(q, engine)
# Out:
#    Tables_in_chinook
# 0              album
# 1             artist
# 2           customer
# 3           employee
# 4              genre
# 5            invoice
# 6        invoiceline
# 7          mediatype
# 8           playlist
# 9      playlisttrack
# 10             track
